# %% [markdown]
# # Introduction

# %% [markdown]
# ## What is scraping the web?

# %% [markdown]
# ## Why scrape data?

# %% [markdown]
# ## Is this Legal/ Ethical?

# %% [markdown]
# # Programming:

# %%
# Import packages

# Webscraping:
from bs4 import BeautifulSoup
# access the web:
import requests
# data formnatting
import pandas as pd
# text searching:
import re

# %% [markdown]
# # Making the Soup
# https://beautiful-soup-4.readthedocs.io/en/latest/#making-the-soup

# %%
with open("simple_webpage.html") as f:
    _txt_file = f.readlines()
print(_txt_file)
# mess:
# Out:
# ['<!DOCTYPE html>\n', '\n', '<html>\n', '<body>\n', '\n', '<h1>My First Heading</h1>\n', '\n', '<p>My first paragraph.</p>\n', '\n', '<h1>My Second Heading</h1>\n', '\n', '<p>My Second paragraph.</p>\n', '\n', '<h1>My Third Heading</h1>\n', '\n', '<p>My Third paragraph.</p>\n', '\n', '</body>\n', '</html>\n']

# %%
with open("simple_webpage.html") as f:
    soup = BeautifulSoup(f)
print(soup)
# not mess:
# Out:
# <!DOCTYPE html>
# <html>
# <body>
# <h1>My First Heading</h1>
# <p>My first paragraph.</p>
# <h1>My Second Heading</h1>
# <p>My Second paragraph.</p>
# <h1>My Third Heading</h1>
# <p>My Third paragraph.</p>
# </body>
# </html>

# %%
print(type(soup))
# a soup object is a?
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(vars(soup))
# what do they have?
# Out:
# {'builder': <bs4.builder._lxml.LXMLTreeBuilder object at 0x7fb325979f50>, 'is_xml': False, 'known_xml': False, '_namespaces': {'xml': 'http://www.w3.org/XML/1998/namespace'}, 'parse_only': None, 'markup': None, 'original_encoding': None, 'declared_html_encoding': None, 'contains_replacement_characters': False, 'parser_class': <class 'bs4.BeautifulSoup'>, 'name': '[document]', 'namespace': None, 'prefix': None, 'attrs': {}, 'contents': ['html', <html>
# <body>
# <h1>My First Heading</h1>
# <p>My first paragraph.</p>
# <h1>My Second Heading</h1>
# <p>My Second paragraph.</p>
# <h1>My Third Heading</h1>
# <p>My Third paragraph.</p>
# </body>
# </html>, '\n'], 'parent': None, 'previous_element': None, 'next_element': None, 'next_sibling': None, 'previous_sibling': None, 'hidden': 1, 'can_be_empty_element': False, 'cdata_list_attributes': {'*': ['class', 'accesskey', 'dropzone'], 'a': ['rel', 'rev'], 'link': ['rel', 'rev'], 'td': ['headers'], 'th': ['headers'], 'form': ['accept-charset'], 'object': ['archive'], 'area': ['rel'], 'icon': ['sizes'], 'iframe': ['sandbox'], 'output': ['for']}, 'preserve_whitespace_tags': {'textarea', 'pre'}, 'current_data': [], 'currentTag': <!DOCTYPE html>
# <html>
# <body>
# <h1>My First Heading</h1>
# <p>My first paragraph.</p>
# <h1>My Second Heading</h1>
# <p>My Second paragraph.</p>
# <h1>My Third Heading</h1>
# <p>My Third paragraph.</p>
# </body>
# </html>
# , 'tagStack': [<!DOCTYPE html>
# <html>
# <body>
# <h1>My First Heading</h1>
# <p>My first paragraph.</p>
# <h1>My Second Heading</h1>
# <p>My Second paragraph.</p>
# <h1>My Third Heading</h1>
# <p>My Third paragraph.</p>
# </body>
# </html>
# ], 'preserve_whitespace_tag_stack': [], '_most_recent_element': '\n'}

# %%
print(soup.contents)
# Out:
# ['html', <html>
# <body>
# <h1>My First Heading</h1>
# <p>My first paragraph.</p>
# <h1>My Second Heading</h1>
# <p>My Second paragraph.</p>
# <h1>My Third Heading</h1>
# <p>My Third paragraph.</p>
# </body>
# </html>, '\n']

# %%
soup.h1
# Out:
# <h1>My First Heading</h1>

# %%
soup.p
# Out:
# <p>My first paragraph.</p>

# %% [markdown]
# # Kinds of objects
# https://beautiful-soup-4.readthedocs.io/en/latest/#kinds-of-objects

# %% [markdown]
# ## Name

# %%
soup.h1.text
# Out:
# 'My First Heading'

# %% [markdown]
# ## Attributes

# %%
soup.h1['class']
# Produces Key Error
# So add class to html variable
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-992d7318d6e3> in <module>
# ----> 1 soup.h1['class']
#       2 # Produces Key Error
#       3 # So add class to html variable
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#     969         """tag[key] returns the value of the 'key' attribute for the tag,
#     970         and throws an exception if it's not there."""
# --> 971         return self.attrs[key]
#     972
#     973     def __iter__(self):
#
# KeyError: 'class'

# %%
soup.h1['id']

# %% [markdown]
# ## Switch to actor Example

# %%
with open("example_actor_webpage.html") as f:
    soup = BeautifulSoup(f)
print(soup)
# now that our example has more attributes ...

# %%
soup.h1['class']

# %% [markdown]
# ## Text

# %%
soup.h1.text

# %% [markdown]
# ## Links (an attribute)

# %%
soup.a.text

# %%
soup.a['href']

# %% [markdown]
# # Navigating the tree

# %% [markdown]
# ## Going Down

# %% [markdown]
# ### Children

# %%
list(soup.div.children)

# %%
for child in soup.div.children:
    print(child)

# %% [markdown]
# ### Descendants
# Descendant are almost the same as children yet there's one major difference:

# %%
for child in soup.div.descendants:
    print(child)

# %% [markdown]
# ## Going up

# %%
soup.a.parent

# %%
list(soup.a.parents)

# %%
list(soup.a.parents)[0]

# %% [markdown]
# ## Going Sideways

# %%
list(soup.table.tr.td.next_siblings)

# %%
for row in soup.table.contents:
    if row.text == 'Lead':
        print(row)
# Produces Attribute Errpr

# %% [markdown]
# BS4 Gives an error because not all the objects it's returning have a 'text' attribute. Namely the empty strings. You could easily shortcut this with an if statement or try/ except, but that would stretch this class.

# %%
for row in soup.table.tr.td.next_siblings:
    if 'Lead' in row.string:
        print(row.previous_sibling.text)

# %%
soup.table.tr.next_element

# %% [markdown]
# # Searching the tree
# https://beautiful-soup-4.readthedocs.io/en/latest/#searching-the-tree

# %% [markdown]
# ## Filters

# %%
soup.find_all('a')
# Out:
# []

# %%
soup.find_all(['a', 'td'])
# Out:
# []

# %% [markdown]
# ### Function Filter

# %% [markdown]
# A bit more challenging, though very useful.
#
# https://beautiful-soup-4.readthedocs.io/en/latest/index.html?highlight=navigablestring#a-function

# %% [markdown]
# ### Attributes

# %%
soup.find_all(id='movie_title')
# Out:
# []

# %%
soup.find_all('h1', class_='title')
# Out:
# []

# %% [markdown]
# # Into the wild

# %%
webpage = requests.get("https://www.imdb.com/title/tt1302006")

# %%
# print(webpage.content)

# %%
soup = BeautifulSoup(webpage.content)

# %%
# links = soup.find_all('a')
links = soup.find_all(href=True)

# %%
for link in links:
    print(type(link))
    print(link.text)
# Out:
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Showtimes & Tickets
# <class 'bs4.element.Tag'>
# Showtimes & Tickets
# <class 'bs4.element.Tag'>
# Top Rated Movies
# <class 'bs4.element.Tag'>
# Most Popular Movies
# <class 'bs4.element.Tag'>
# Browse by Genre
# <class 'bs4.element.Tag'>
# Top Box Office
# <class 'bs4.element.Tag'>
# In Theaters
# <class 'bs4.element.Tag'>
# Coming Soon
# <class 'bs4.element.Tag'>
# Coming Soon
# <class 'bs4.element.Tag'>
# DVD & Blu-Ray Releases
# <class 'bs4.element.Tag'>
# Release Calendar
# <class 'bs4.element.Tag'>
# Movie News
# <class 'bs4.element.Tag'>
# India Spotlight
# <class 'bs4.element.Tag'>
# Top Rated Shows
# <class 'bs4.element.Tag'>
# Most Popular Shows
# <class 'bs4.element.Tag'>
# Browse by Genre
# <class 'bs4.element.Tag'>
# TV News
# <class 'bs4.element.Tag'>
# India Spotlight
# <class 'bs4.element.Tag'>
# Oscars
# <class 'bs4.element.Tag'>
# Best Picture Winners
# <class 'bs4.element.Tag'>
# Best Picture Winners
# <class 'bs4.element.Tag'>
# Golden Globes
# <class 'bs4.element.Tag'>
# Emmys
# <class 'bs4.element.Tag'>
# San Diego Comic Con
# <class 'bs4.element.Tag'>
# New York Comic Con
# <class 'bs4.element.Tag'>
# Sundance
# <class 'bs4.element.Tag'>
# Toronto Int'l Film Festival
# <class 'bs4.element.Tag'>
# Awards Central
# <class 'bs4.element.Tag'>
# Festival Central
# <class 'bs4.element.Tag'>
# All Events
# <class 'bs4.element.Tag'>
# Born Today
# <class 'bs4.element.Tag'>
# Most Popular Celebs
# <class 'bs4.element.Tag'>
# Most Popular Celebs
# <class 'bs4.element.Tag'>
# Celebrity News
# <class 'bs4.element.Tag'>
# IMDb Originals
# <class 'bs4.element.Tag'>
# Latest Trailers
# <class 'bs4.element.Tag'>
# Help Center
# <class 'bs4.element.Tag'>
# Contributor Zone
# <class 'bs4.element.Tag'>
# Polls
# <class 'bs4.element.Tag'>
# For Industry Professionals
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Advanced Search
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Watchlist
# <class 'bs4.element.Tag'>
# Sign In
# <class 'bs4.element.Tag'>
# FULL CAST AND CREW
# <class 'bs4.element.Tag'>
# TRIVIA
# <class 'bs4.element.Tag'>
# USER REVIEWS
# <class 'bs4.element.Tag'>
# IMDbPro
# <class 'bs4.element.Tag'>
# View
# <class 'bs4.element.Tag'>
# Full Cast and Crew
# <class 'bs4.element.Tag'>
# Release Dates
# <class 'bs4.element.Tag'>
# Official Sites
# <class 'bs4.element.Tag'>
# Company Credits
# <class 'bs4.element.Tag'>
# Filming & Production
# <class 'bs4.element.Tag'>
# Technical Specs
# <class 'bs4.element.Tag'>
# Taglines
# <class 'bs4.element.Tag'>
# Plot Summary
# <class 'bs4.element.Tag'>
# Synopsis
# <class 'bs4.element.Tag'>
# Plot Keywords
# <class 'bs4.element.Tag'>
# Parents Guide
# <class 'bs4.element.Tag'>
# News
# <class 'bs4.element.Tag'>
# External Sites
# <class 'bs4.element.Tag'>
# Awards
# <class 'bs4.element.Tag'>
# FAQ
# <class 'bs4.element.Tag'>
# User Reviews
# <class 'bs4.element.Tag'>
# User Ratings
# <class 'bs4.element.Tag'>
# External Reviews
# <class 'bs4.element.Tag'>
# Metacritic Reviews
# <class 'bs4.element.Tag'>
# Photo Gallery
# <class 'bs4.element.Tag'>
# Trailers and Videos
# <class 'bs4.element.Tag'>
# Trivia
# <class 'bs4.element.Tag'>
# Goofs
# <class 'bs4.element.Tag'>
# Crazy Credits
# <class 'bs4.element.Tag'>
# Quotes
# <class 'bs4.element.Tag'>
# Alternate Versions
# <class 'bs4.element.Tag'>
# Connections
# <class 'bs4.element.Tag'>
# Soundtracks
# <class 'bs4.element.Tag'>
# 122,486
# <class 'bs4.element.Tag'>
# 2019
# <class 'bs4.element.Tag'>
# Biography
# <class 'bs4.element.Tag'>
# Crime
# <class 'bs4.element.Tag'>
# Drama
# <class 'bs4.element.Tag'>
# 27 November 2019 (USA)
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
#
#
# <class 'bs4.element.Tag'>
# 18 VIDEOS
# <class 'bs4.element.Tag'>
# 264 IMAGES
# <class 'bs4.element.Tag'>
# Jimmy Hoffa
# <class 'bs4.element.Tag'>
# Martin Scorsese
# <class 'bs4.element.Tag'>
# Charles Brandt
# <class 'bs4.element.Tag'>
# Steven Zaillian
# <class 'bs4.element.Tag'>
# Robert De Niro
# <class 'bs4.element.Tag'>
# Al Pacino
# <class 'bs4.element.Tag'>
# Joe Pesci
# <class 'bs4.element.Tag'>
# See full cast & crew
# <class 'bs4.element.Tag'>
#
# 94
#
# <class 'bs4.element.Tag'>
#
# Metascore
#
# <class 'bs4.element.Tag'>
# metacritic.com
# <class 'bs4.element.Tag'>
# 1,744 user
# <class 'bs4.element.Tag'>
# 347 critic
# <class 'bs4.element.Tag'>
#
#
# View production, box office, & company info
#
#
#
# <class 'bs4.element.Tag'>
#   Lizzy Caplan Shares an Awkward "Masters of Sex" Story
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Lizzy Caplan
# <class 'bs4.element.Tag'>
#  Watch now
# <class 'bs4.element.Tag'>
#  UK box office preview: ‘Jumanji: The Next Level’ aims to thaw ‘Frozen II’
#
# <class 'bs4.element.Tag'>
#  ‘6 Underground’ Review: Dir. Michael Bay (2019)
#
# <class 'bs4.element.Tag'>
#  Who turned out the lights? How the decade's final month changed cinema for ever
#
# <class 'bs4.element.Tag'>
# See all related articles
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# Top 10 Most Anticipated Movies of 2019
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# Editors' Picks: Week of Aug. 30, 2019
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# 2019 Oscars Wow and WTF Moments
#
# <class 'bs4.element.Tag'>
# Create a list
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# Movies
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# Best movies 2019 by metascore
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# 2019
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# Best to Worst of 2019
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# Best of 2019
#
# <class 'bs4.element.Tag'>
# See all related lists
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Login
# <class 'bs4.element.Tag'>
# Show HTML
# <class 'bs4.element.Tag'>
# View more styles
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Movies That Will Keep You at the Edge of Your Seat Come 2018
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Favorite Steven Zaillian Screenplay
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Face-Off: 'Once Upon a Time in Hollywood' vs. 'The Irishman'
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# The 20 Best Needle Drops in Martin Scorsese Movies
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# The Best 2010s Biography Movie
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Honest Movie Titles (2019 Edition)
# <class 'bs4.element.Tag'>
# See more polls »
# <class 'bs4.element.Tag'>
#   Why 'The Irishman' Is Scorsese's MCU Movie
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Martin Scorsese
# <class 'bs4.element.Tag'>
# The Irishman
# <class 'bs4.element.Tag'>
#  Watch now
# <class 'bs4.element.Tag'>
#  Top Rated Movies #147
#
# <class 'bs4.element.Tag'>
# See more awards
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  See all 18 videos
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  See all
# 264 photos
# <class 'bs4.element.Tag'>
# Learn more
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Once Upon a Time... in Hollywood
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Joker
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Goodfellas
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Casino
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# The King
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Avengers: Endgame
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
# Avengers: Infinity War
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Gisaengchung
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Marriage Story
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Taxi Driver
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Ford v Ferrari
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# The Godfather
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
#
#
# <class 'bs4.element.Tag'>
# Us
# <class 'bs4.element.Tag'>
# 1
# <class 'bs4.element.Tag'>
# 2
# <class 'bs4.element.Tag'>
# 3
# <class 'bs4.element.Tag'>
# 4
# <class 'bs4.element.Tag'>
# 5
# <class 'bs4.element.Tag'>
# 6
# <class 'bs4.element.Tag'>
# 7
# <class 'bs4.element.Tag'>
# 8
# <class 'bs4.element.Tag'>
# 9
# <class 'bs4.element.Tag'>
# 10
# <class 'bs4.element.Tag'>
# X
# <class 'bs4.element.Tag'>
# Edit
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Robert De Niro
#
# <class 'bs4.element.Tag'>
# Frank Sheeran
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Al Pacino
#
# <class 'bs4.element.Tag'>
# Jimmy Hoffa
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Joe Pesci
#
# <class 'bs4.element.Tag'>
# Russell Bufalino
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Harvey Keitel
#
# <class 'bs4.element.Tag'>
# Angelo Bruno
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Ray Romano
#
# <class 'bs4.element.Tag'>
# Bill Bufalino
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Bobby Cannavale
#
# <class 'bs4.element.Tag'>
# Skinny Razor
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Anna Paquin
#
# <class 'bs4.element.Tag'>
# Older Peggy Sheeran
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Stephen Graham
#
# <class 'bs4.element.Tag'>
# Anthony 'Tony Pro' Provenzano
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Stephanie Kurtzuba
#
# <class 'bs4.element.Tag'>
# Irene Sheeran
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Jack Huston
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Kathrine Narducci
#
# <class 'bs4.element.Tag'>
# Carrie Bufalino
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Jesse Plemons
#
# <class 'bs4.element.Tag'>
# Chuckie O'Brien
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Domenick Lombardozzi
#
# <class 'bs4.element.Tag'>
# Fat Tony Salerno
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Paul Herman
#
# <class 'bs4.element.Tag'>
# Whispers DiTullio
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Gary Basaraba
#
# <class 'bs4.element.Tag'>
# See full cast
# <class 'bs4.element.Tag'>
#
#
# View production, box office, & company info
#
#
#
# <class 'bs4.element.Tag'>
# Edit
# <class 'bs4.element.Tag'>
# bcarruthers-76500
# <class 'bs4.element.Tag'>
# Plot Summary
# <class 'bs4.element.Tag'>
# Add Synopsis
# <class 'bs4.element.Tag'>
#  nonlinear timeline
# <class 'bs4.element.Tag'>
#  criminal as protagonist
# <class 'bs4.element.Tag'>
#  killer as protagonist
# <class 'bs4.element.Tag'>
#  murder
# <class 'bs4.element.Tag'>
#  truck driver
# <class 'bs4.element.Tag'>
# See All (186)
# <class 'bs4.element.Tag'>
#  See more
# <class 'bs4.element.Tag'>
#  Biography
# <class 'bs4.element.Tag'>
#  Crime
# <class 'bs4.element.Tag'>
#  Drama
# <class 'bs4.element.Tag'>
# MPAA
# <class 'bs4.element.Tag'>
#  See all certifications
# <class 'bs4.element.Tag'>
#  View content advisory
# <class 'bs4.element.Tag'>
# Edit
# <class 'bs4.element.Tag'>
# Official Facebook
# <class 'bs4.element.Tag'>
# Official Instagram
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# USA
# <class 'bs4.element.Tag'>
# English
# <class 'bs4.element.Tag'>
# Italian
# <class 'bs4.element.Tag'>
# Latin
# <class 'bs4.element.Tag'>
# Spanish
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# New Jersey, USA
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# Edit
# <class 'bs4.element.Tag'>
# See more on IMDbPro
# <class 'bs4.element.Tag'>
#  Tribeca Productions
# <class 'bs4.element.Tag'>
#  Sikelia Productions
# <class 'bs4.element.Tag'>
#  Winkler Films
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# IMDbPro
# <class 'bs4.element.Tag'>
# Dolby Atmos
# <class 'bs4.element.Tag'>
# Color
# <class 'bs4.element.Tag'>
# Color
# <class 'bs4.element.Tag'>
# full technical specs
# <class 'bs4.element.Tag'>
# Edit
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# Frank Sheeran
# <class 'bs4.element.Tag'>
# Frank Sheeran
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# The Godfather
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# Dámaso Pérez Prado
# <class 'bs4.element.Tag'>
# Dámaso Pérez Prado
# <class 'bs4.element.Tag'>
# Perez Prado Orchestra
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
#  Does Steve Van Zandt really sing in his scene?
# <class 'bs4.element.Tag'>
#  What is the meaning of the water on the back seat and fish delivery discussion during the pick up of Hoffa before he gets killed?
# <class 'bs4.element.Tag'>
#  Should I watch Goodfellas before I watch The Irishman?
# <class 'bs4.element.Tag'>
# See more
# <class 'bs4.element.Tag'>
# Her-Excellency
# <class 'bs4.element.Tag'>
# See all my reviews
# <class 'bs4.element.Tag'>
# Report this
# <class 'bs4.element.Tag'>
# Review this title
# <class 'bs4.element.Tag'>
# See all 1,744 user reviews
# <class 'bs4.element.Tag'>
# Getting Started
# <class 'bs4.element.Tag'>
# Contributor Zone
# <class 'bs4.element.Tag'>
#   Stream Popular Action and Adventure Titles With Prime Video
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#  Start your free trial
# <class 'bs4.element.Tag'>
# Clear your history
# <class 'bs4.element.Tag'>
# Get the IMDb App
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
#
# <class 'bs4.element.Tag'>
# Get the IMDb App
# <class 'bs4.element.Tag'>
# View Full Site
# <class 'bs4.element.Tag'>
# Help
# <class 'bs4.element.Tag'>
# Site Index
# <class 'bs4.element.Tag'>
# IMDb Pro
# <class 'bs4.element.Tag'>
# Box Office Mojo
# <class 'bs4.element.Tag'>
# Press Room
# <class 'bs4.element.Tag'>
# Advertising
# <class 'bs4.element.Tag'>
# Jobs
# <class 'bs4.element.Tag'>
# Conditions of Use
# <class 'bs4.element.Tag'>
# Privacy Policy
# <class 'bs4.element.Tag'>
# Interest-Based Ads

# %%
links[0]
# Out:
# <link href="https://www.imdb.com/title/tt1302006/" rel="canonical"/>

# %%
my_links = []

for link in links:
    wrapped = {'text':link.text,'url':link['href']}
    my_links.append(wrapped)

# %%
# my_links
# # we get a lot of empty text fields

# %% [markdown]
# # Presenting our Data

# %%
df = pd.DataFrame(my_links)

# %%
df
# Out:
#                     text                                                url
# 0                                     https://www.imdb.com/title/tt1302006/
# 1                                       https://m.imdb.com/title/tt1302006/
# 2                         https://m.media-amazon.com/images/G/01/imdb/im...
# 3                         https://m.media-amazon.com/images/G/01/imdb/im...
# 4                         https://m.media-amazon.com/images/G/01/imdb/im...
# ..                   ...                                                ...
# 482         Advertising   https://advertising.amazon.com/products/displa...
# 483                Jobs    https://www.amazon.jobs/en/teams/imdb?ref_=ft_jb
# 484    Conditions of Use                            /conditions?ref_=ft_cou
# 485       Privacy Policy                               /privacy?ref_=ft_pvc
# 486  Interest-Based Ads   /offsite/?page-action=ft-iba&token=BCYkHHPYZ88...
#
# [487 rows x 2 columns]

# %% [markdown]
# ## Bonus Pandas Tricks

# %%
df.loc[df.text.str.len() > 0]
# Out:
#                     text                                                url
# 16   Showtimes & Tickets      https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# 17   Showtimes & Tickets  https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# 18      Top Rated Movies                         /chart/top/?ref_=nv_mv_250
# 19   Most Popular Movies                  /chart/moviemeter/?ref_=nv_mv_mpm
# 20       Browse by Genre  https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# ..                   ...                                                ...
# 482         Advertising   https://advertising.amazon.com/products/displa...
# 483                Jobs    https://www.amazon.jobs/en/teams/imdb?ref_=ft_jb
# 484    Conditions of Use                            /conditions?ref_=ft_cou
# 485       Privacy Policy                               /privacy?ref_=ft_pvc
# 486  Interest-Based Ads   /offsite/?page-action=ft-iba&token=BCYkHHPYZ88...
#
# [425 rows x 2 columns]

# %%
_df_http = df.loc[df['url'].str.startswith('http')]
# Pandas documentation https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.startswith.html

# %%
_df_http.loc[df.text.str.len() > 0]
# Out:
#                                                   text  \
# 16                                 Showtimes & Tickets
# 17                                 Showtimes & Tickets
# 20                                     Browse by Genre
# 22                                         In Theaters
# 23                                         Coming Soon
# 24                                         Coming Soon
# 25                              DVD & Blu-Ray Releases
# 26                                    Release Calendar
# 31                                     Browse by Genre
# 35                                Best Picture Winners
# 36                                Best Picture Winners
# 45                                          All Events
# 47                                 Most Popular Celebs
# 48                                 Most Popular Celebs
# 52                                         Help Center
# 53                                    Contributor Zone
# 55                          For Industry Professionals
# 57                                     Advanced Search
# 64                                             IMDbPro
# 114                                     metacritic.com
# 117   \n\nView production, box office, & company in...
# 180                                         Learn more
# 395   \n\nView production, box office, & company in...
# 399                                       Add Synopsis
# 427                                See more on IMDbPro
# 432                                            IMDbPro
# 459                                    Getting Started
# 477                                              Help
# 478                                        Site Index
# 479                                          IMDb Pro
# 480                                   Box Office Mojo
# 481                                         Press Room
# 482                                       Advertising
# 483                                              Jobs
#
#                                                    url
# 16       https://www.imdb.com/showtimes/?ref_=nv_mv_sh
# 17   https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
# 20   https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
# 22   https://www.imdb.com/movies-in-theaters?ref_=n...
# 23       https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
# 24   https://www.imdb.com/movies-coming-soon/?ref_=...
# 25   https://www.imdb.com/list/ls016522954/?ref_=nv...
# 26       https://www.imdb.com/calendar/?ref_=nv_mv_cal
# 31   https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
# 35   https://m.imdb.com/chart/bestpicture/?ref_=nv_...
# 36   https://www.imdb.com/search/title/?count=100&g...
# 45      https://www.imdb.com/event/all/?ref_=nv_ev_all
# 47   https://m.imdb.com/chart/starmeter/?ref_=nv_cel_m
# 48   https://www.imdb.com/search/name/?gender=male%...
# 52         https://help.imdb.com/imdb?ref_=cons_nb_hlp
# 53     https://contribute.imdb.com/czone?ref_=nv_cm_cz
# 55   https://pro.imdb.com?ref_=cons_nb_hm&rf=cons_n...
# 57                        https://www.imdb.com/search/
# 64   https://pro.imdb.com/title/tt1302006?rf=cons_t...
# 114                          http://www.metacritic.com
# 117  https://pro.imdb.com/title/tt1302006?rf=cons_t...
# 180  https://help.imdb.com/article/imdb/discover-wa...
# 395  https://pro.imdb.com/title/tt1302006?rf=cons_t...
# 399  https://contribute.imdb.com/updates?update=tt1...
# 427  https://pro.imdb.com/title/tt1302006?rf=cons_t...
# 432  https://pro.imdb.com/title/tt1302006/companycr...
# 459  https://help.imdb.com/article/contribution/con...
# 477             https://help.imdb.com/imdb?ref_=ft_hlp
# 478  https://help.imdb.com/article/imdb/general-inf...
# 479         https://pro.imdb.com?ref_=ft_pro&rf=ft_pro
# 480                      https://www.boxofficemojo.com
# 481         https://www.imdb.com/pressroom/?ref_=ft_pr
# 482  https://advertising.amazon.com/products/displa...
# 483   https://www.amazon.jobs/en/teams/imdb?ref_=ft_jb

# %%
df.loc[df.text.str.contains('Scorsese')]
# Out:
#                                                   text  \
# 105                                    Martin Scorsese
# 155  The 20 Best Needle Drops in Martin Scorsese Mo...
# 161        Why 'The Irishman' Is Scorsese's MCU Movie
# 163                                    Martin Scorsese
#
#                                             url
# 105                            /name/nm0000217/
# 155                          /poll/9Ng3cN69oG0/
# 161  /list/ls025720609/videoplayer/vi3425746713
# 163                             /name/nm0000217

# %% [markdown]
# # Applying what we know

# %% [markdown]
# ## What genre of films do actors mainly work in?

# %%
actor = requests.get('https://www.imdb.com/name/nm0000134/?ref_=tt_cl_t1')

# %%
soup = BeautifulSoup(actor.content)

# %% [markdown]
# ### Getting into the Filmography

# %%
filmography = soup.find(id='filmography')

# %%
# actor_filmography = filmography.find('div', {'data-category' : 'actor'}).find_next('div', class_='filmo-category-section')

# %%
# Break up the above
actor_filmography = filmography.find('div', {'data-category' : 'actor'})
actor_filmography = actor_filmography.find_next('div', class_='filmo-category-section')

# %%
film_links = actor_filmography.find_all(href=True)

# %% [markdown]
# ## Let's see those links

# %%
for link in film_links:
    print(link['href'])
# Out:
# /title/tt4075436/
# https://pro.imdb.com/title/tt4075436?rf=cons_nm_filmo
# /title/tt3143812/
# https://pro.imdb.com/title/tt3143812?rf=cons_nm_filmo
# /title/tt5537002/
# https://pro.imdb.com/title/tt5537002?rf=cons_nm_filmo
# /title/tt5420210/
# https://pro.imdb.com/title/tt5420210?rf=cons_nm_filmo
# /title/tt4532038/
# https://pro.imdb.com/title/tt4532038?rf=cons_nm_filmo
# /title/tt1302006/
# /title/tt7286456/
# /title/tt0072562/
# /title/tt10213386/
# /title/tt10023542/
# /title/tt9349000/
# /title/tt9348996/
# /title/tt9264524/
# #
# /title/tt1933667/
# /title/tt1967614/
# /title/tt1781827/
# /title/tt1860213/
# /title/tt2446980/
# /title/tt3276924/
# /title/tt5227516/
# /title/tt4016250/
# /title/tt2361509/
# /title/tt10908058/
# /title/tt2212008/
# /title/tt1661382/
# /title/tt1800241/
# /title/tt1204975/
# /title/tt2404311/
# /title/tt1480295/
# /title/tt1931435/
# /title/tt1045658/
# /title/tt1815708/
# /title/tt0455323/
# /title/tt1748179/
# /title/tt1598822/
# /title/tt1448755/
# /title/tt6779822/
# /title/tt6779974/
# /title/tt6780018/
# /title/tt1219289/
# /title/tt1712187/
# /title/tt0496424/
# /title/tt1635809/
# /title/tt0970866/
# /title/tt1423995/
# /title/tt0985694/
# /title/tt0780511/
# /title/tt1034331/
# /title/tt0486674/
# /title/tt0486655/
# /title/tt3492560/
# /title/tt0343737/
# /title/tt0344854/
# /title/tt0445114/
# /title/tt0876622/
# /title/tt5091774/
# /title/tt0382077/
# /title/tt0356443/
# /title/tt0290002/
# /title/tt0307453/
# /title/tt0335121/
# /title/tt0289848/
# /title/tt0269095/
# /title/tt0284490/
# /title/tt0227445/
# /title/tt0179626/
# /title/tt0212338/
# /title/tt0203019/
# /title/tt0131704/
# /title/tt0155711/
# /title/tt0122933/
# /title/tt0122690/
# /title/tt0119223/
# /title/tt0120885/
# /title/tt0119396/
# /title/tt0118887/
# /title/tt0116999/
# /title/tt0117665/
# /title/tt0116277/
# /title/tt0113277/
# /title/tt0112641/
# /title/tt0112654/
# /title/tt0109836/
# /title/tt0106489/
# /title/tt0108330/
# /title/tt0107473/
# /title/tt0105001/
# /title/tt0104892/
# /title/tt0101540/
# /title/tt0101393/
# /title/tt0101984/
# /title/tt0099077/
# /title/tt0099685/
# /title/tt0100680/
# /title/tt0098625/
# /title/tt0097607/
# /title/tt0095631/
# /title/tt0092851/
# /title/tt0094226/
# /title/tt0092563/
# /title/tt0091530/
# /title/tt0088846/
# /title/tt0087233/
# /title/tt0087843/
# /title/tt0085794/
# /title/tt0083232/
# /title/tt0081398/
# /title/tt0077416/
# /title/tt0809488/
# /title/tt1295453/
# /title/tt1295452/
# /title/tt1295451/
# /title/tt1295450/
# /title/tt0076451/
# /title/tt0074777/
# /title/tt0074084/
# /title/tt0075314/
# /title/tt0071562/
# /title/tt0070379/
# /title/tt0069765/
# /title/tt0067124/
# /title/tt0066856/
# /title/tt0067266/
# /title/tt0065836/
# /title/tt0065481/
# /title/tt0064924/
# /title/tt0065198/
# /title/tt0063036/
# /title/tt0063154/
# /title/tt2141713/
# /title/tt0179492/

# %%
baselink = 'https://www.imdb.com'
for link in film_links:
    if link['href'].startswith('/'):
        print(baselink + link['href'])
# Out:
# https://www.imdb.com/title/tt4075436/
# https://www.imdb.com/title/tt3143812/
# https://www.imdb.com/title/tt5537002/
# https://www.imdb.com/title/tt5420210/
# https://www.imdb.com/title/tt4532038/
# https://www.imdb.com/title/tt1302006/
# https://www.imdb.com/title/tt7286456/
# https://www.imdb.com/title/tt0072562/
# https://www.imdb.com/title/tt10213386/
# https://www.imdb.com/title/tt10023542/
# https://www.imdb.com/title/tt9349000/
# https://www.imdb.com/title/tt9348996/
# https://www.imdb.com/title/tt9264524/
# https://www.imdb.com/title/tt1933667/
# https://www.imdb.com/title/tt1967614/
# https://www.imdb.com/title/tt1781827/
# https://www.imdb.com/title/tt1860213/
# https://www.imdb.com/title/tt2446980/
# https://www.imdb.com/title/tt3276924/
# https://www.imdb.com/title/tt5227516/
# https://www.imdb.com/title/tt4016250/
# https://www.imdb.com/title/tt2361509/
# https://www.imdb.com/title/tt10908058/
# https://www.imdb.com/title/tt2212008/
# https://www.imdb.com/title/tt1661382/
# https://www.imdb.com/title/tt1800241/
# https://www.imdb.com/title/tt1204975/
# https://www.imdb.com/title/tt2404311/
# https://www.imdb.com/title/tt1480295/
# https://www.imdb.com/title/tt1931435/
# https://www.imdb.com/title/tt1045658/
# https://www.imdb.com/title/tt1815708/
# https://www.imdb.com/title/tt0455323/
# https://www.imdb.com/title/tt1748179/
# https://www.imdb.com/title/tt1598822/
# https://www.imdb.com/title/tt1448755/
# https://www.imdb.com/title/tt6779822/
# https://www.imdb.com/title/tt6779974/
# https://www.imdb.com/title/tt6780018/
# https://www.imdb.com/title/tt1219289/
# https://www.imdb.com/title/tt1712187/
# https://www.imdb.com/title/tt0496424/
# https://www.imdb.com/title/tt1635809/
# https://www.imdb.com/title/tt0970866/
# https://www.imdb.com/title/tt1423995/
# https://www.imdb.com/title/tt0985694/
# https://www.imdb.com/title/tt0780511/
# https://www.imdb.com/title/tt1034331/
# https://www.imdb.com/title/tt0486674/
# https://www.imdb.com/title/tt0486655/
# https://www.imdb.com/title/tt3492560/
# https://www.imdb.com/title/tt0343737/
# https://www.imdb.com/title/tt0344854/
# https://www.imdb.com/title/tt0445114/
# https://www.imdb.com/title/tt0876622/
# https://www.imdb.com/title/tt5091774/
# https://www.imdb.com/title/tt0382077/
# https://www.imdb.com/title/tt0356443/
# https://www.imdb.com/title/tt0290002/
# https://www.imdb.com/title/tt0307453/
# https://www.imdb.com/title/tt0335121/
# https://www.imdb.com/title/tt0289848/
# https://www.imdb.com/title/tt0269095/
# https://www.imdb.com/title/tt0284490/
# https://www.imdb.com/title/tt0227445/
# https://www.imdb.com/title/tt0179626/
# https://www.imdb.com/title/tt0212338/
# https://www.imdb.com/title/tt0203019/
# https://www.imdb.com/title/tt0131704/
# https://www.imdb.com/title/tt0155711/
# https://www.imdb.com/title/tt0122933/
# https://www.imdb.com/title/tt0122690/
# https://www.imdb.com/title/tt0119223/
# https://www.imdb.com/title/tt0120885/
# https://www.imdb.com/title/tt0119396/
# https://www.imdb.com/title/tt0118887/
# https://www.imdb.com/title/tt0116999/
# https://www.imdb.com/title/tt0117665/
# https://www.imdb.com/title/tt0116277/
# https://www.imdb.com/title/tt0113277/
# https://www.imdb.com/title/tt0112641/
# https://www.imdb.com/title/tt0112654/
# https://www.imdb.com/title/tt0109836/
# https://www.imdb.com/title/tt0106489/
# https://www.imdb.com/title/tt0108330/
# https://www.imdb.com/title/tt0107473/
# https://www.imdb.com/title/tt0105001/
# https://www.imdb.com/title/tt0104892/
# https://www.imdb.com/title/tt0101540/
# https://www.imdb.com/title/tt0101393/
# https://www.imdb.com/title/tt0101984/
# https://www.imdb.com/title/tt0099077/
# https://www.imdb.com/title/tt0099685/
# https://www.imdb.com/title/tt0100680/
# https://www.imdb.com/title/tt0098625/
# https://www.imdb.com/title/tt0097607/
# https://www.imdb.com/title/tt0095631/
# https://www.imdb.com/title/tt0092851/
# https://www.imdb.com/title/tt0094226/
# https://www.imdb.com/title/tt0092563/
# https://www.imdb.com/title/tt0091530/
# https://www.imdb.com/title/tt0088846/
# https://www.imdb.com/title/tt0087233/
# https://www.imdb.com/title/tt0087843/
# https://www.imdb.com/title/tt0085794/
# https://www.imdb.com/title/tt0083232/
# https://www.imdb.com/title/tt0081398/
# https://www.imdb.com/title/tt0077416/
# https://www.imdb.com/title/tt0809488/
# https://www.imdb.com/title/tt1295453/
# https://www.imdb.com/title/tt1295452/
# https://www.imdb.com/title/tt1295451/
# https://www.imdb.com/title/tt1295450/
# https://www.imdb.com/title/tt0076451/
# https://www.imdb.com/title/tt0074777/
# https://www.imdb.com/title/tt0074084/
# https://www.imdb.com/title/tt0075314/
# https://www.imdb.com/title/tt0071562/
# https://www.imdb.com/title/tt0070379/
# https://www.imdb.com/title/tt0069765/
# https://www.imdb.com/title/tt0067124/
# https://www.imdb.com/title/tt0066856/
# https://www.imdb.com/title/tt0067266/
# https://www.imdb.com/title/tt0065836/
# https://www.imdb.com/title/tt0065481/
# https://www.imdb.com/title/tt0064924/
# https://www.imdb.com/title/tt0065198/
# https://www.imdb.com/title/tt0063036/
# https://www.imdb.com/title/tt0063154/
# https://www.imdb.com/title/tt2141713/
# https://www.imdb.com/title/tt0179492/

# %% [markdown]
# ## Collecting Genres

# %%
baselink = 'https://www.imdb.com'
for link in film_links[:5]:
    if link['href'].startswith('/'):
        
        # CRAWL into another page
        
        url = baselink + link['href']
        page = requests.get(url)
        soup = BeautifulSoup(page.content)

        subtext = soup.find('div', class_='subtext').find_all(href=True)
        print(subtext)
# Out:
# [<a href="/search/title?genres=action&amp;explore=title_type,genres">Action</a>]
# [<a href="/search/title?genres=crime&amp;explore=title_type,genres">Crime</a>, <a href="/search/title?genres=drama&amp;explore=title_type,genres">Drama</a>]
# [<a href="/search/title?genres=crime&amp;explore=title_type,genres">Crime</a>, <a href="/search/title?genres=drama&amp;explore=title_type,genres">Drama</a>, <a href="/search/title?genres=history&amp;explore=title_type,genres">History</a>, <a href="/title/tt5537002/releaseinfo" title="See more release dates">2021 (USA)
# </a>]

# %%
baselink = 'https://www.imdb.com'

# Somewhere to store our genres:
genres = []

# to search our for genre:
genre = re.compile('genre')
    
for link in film_links[:5]:
    if link['href'].startswith('/'):
        url = baselink + link['href']
        page = requests.get(url)
        soup = BeautifulSoup(page.content)
        subtext = soup.find('div', class_='subtext').find_all(href=genre, text=True)
        for g in subtext:
            genres.append(g.text)

# %%
genres
# Out:
# ['Action', 'Crime', 'Drama', 'Crime', 'Drama', 'History']

# %% [markdown]
# ### Collecting more actors

# %%
name = re.compile('name')
actors = []
cache = []

for link in film_links[:5]:
    if link['href'].startswith('/'):
        url = baselink + link['href']
        page = requests.get(url)
        soup = BeautifulSoup(page.content)
        _actors = soup.find('table', class_='cast_list').find_all(href=name, text=True)
        for a in _actors:
            actors.append(a.text.strip('\n')[1:])
            cache.append(baselink+a['href'])

# %%
actors
# Out:
# ['Robert De Niro',
#  'Edgar Ramírez',
#  'Robert De Niro',
#  'Chloë Grace Moretz',
#  'Shailene Woodley',
#  'Miles Teller',
#  'Robert De Niro',
#  'Leonardo DiCaprio']

# %%
cache
# Out:
# ['https://www.imdb.com/name/nm0000134/',
#  'https://www.imdb.com/name/nm1183149/',
#  'https://www.imdb.com/name/nm0000134/',
#  'https://www.imdb.com/name/nm1631269/',
#  'https://www.imdb.com/name/nm0940362/',
#  'https://www.imdb.com/name/nm1886602/',
#  'https://www.imdb.com/name/nm0000134/',
#  'https://www.imdb.com/name/nm0000138/']

# %% [markdown]
# ## Crawling

# %%
cache = ['https://www.imdb.com/title/tt1302006']
log  = []
limit = 20

# %%
films = []

# %%
baselink = 'https://www.imdb.com'

# %%
genre = re.compile('genre')
name = re.compile('name')
title = re.compile('title')

# %%
while len(films) < limit:
    for film_link in cache[:limit]:
        # Check that the film is new
        if film_link not in log:
            # make the soup           
            webpage = requests.get(film_link)
            soup = BeautifulSoup(webpage.content)
            
            # get the film title
            film_name = soup.find('h1').text.strip('\n')
            
            # get the film genres
            genres = []
            _genres = soup.find('div', class_='subtext').find_all(href=genre, text=True)
            for g in _genres:
                genres.append(g.text)
            
            # get the film actors
            actors = []
            _actors = soup.find('table', class_='cast_list').find_all(href=name, text=True)
            for a in _actors:
                actors.append(a.text)
            
            # get the films duration
            duration = soup.find('div', class_='subtext').find('time', text=True).text
            
            # record where we've been
            log.append(film_link)
            
            # get the next films from this ones 'related'
            more_films = soup.find('div', class_='rec_page').find_all('a')
            _cache = [baselink+x['href'] for x in more_films if x not in log]
            
            # save the film data:
            films.append({'film_name': film_name, 'genres' : genres, 'actors': actors, 'duration':duration})

    cache = _cache

# %% [markdown]
# # Present out data in Pandas

# %%
df = pd.DataFrame(films)

# %%
df
# Out:
#                                           film_name  \
# 0                              The Irishman (2019)
# 1          Once Upon a Time... in Hollywood (2019)
# 2                                     Joker (2019)
# 3                                Goodfellas (1990)
# 4                                    Casino (1995)
# 5                                  The King (2019)
# 6                         Avengers: Endgame (2019)
# 7                            Captain Marvel (2019)
# 8                    Avengers: Infinity War (2018)
# 9   Star Wars: Episode VIII - The Last Jedi (2017)
# 10                           Thor: Ragnarok (2017)
# 11                           It Chapter Two (2019)
# 12                                       It (2017)
# 13                                       Us (2019)
# 14                                  Get Out (2017)
# 15                            A Quiet Place (2018)
# 16                                    Split (2016)
# 17                               Hereditary (2018)
# 18                            The Conjuring (2013)
# 19                          The Conjuring 2 (2016)
# 20                                Insidious (2010)
# 21                      Annabelle: Creation (2017)
# 22                     Insidious: Chapter 2 (2013)
# 23                                Annabelle (2014)
# 24                                 Sinister (2012)
#
#                           genres  \
# 0      [Biography, Crime, Drama]
# 1                [Comedy, Drama]
# 2       [Crime, Drama, Thriller]
# 3      [Biography, Crime, Drama]
# 4                 [Crime, Drama]
# 5    [Biography, Drama, History]
# 6     [Action, Adventure, Drama]
# 7    [Action, Adventure, Sci-Fi]
# 8    [Action, Adventure, Sci-Fi]
# 9   [Action, Adventure, Fantasy]
# 10   [Action, Adventure, Comedy]
# 11      [Drama, Fantasy, Horror]
# 12                      [Horror]
# 13   [Horror, Mystery, Thriller]
# 14   [Horror, Mystery, Thriller]
# 15       [Drama, Horror, Sci-Fi]
# 16            [Horror, Thriller]
# 17      [Drama, Horror, Mystery]
# 18   [Horror, Mystery, Thriller]
# 19   [Horror, Mystery, Thriller]
# 20   [Horror, Mystery, Thriller]
# 21   [Horror, Mystery, Thriller]
# 22   [Horror, Mystery, Thriller]
# 23   [Horror, Mystery, Thriller]
# 24   [Horror, Mystery, Thriller]
#
#                                                actors  \
# 0   [ Robert De Niro\n,  Al Pacino\n,  Joe Pesci\n...
# 1   [ Leonardo DiCaprio\n,  Brad Pitt\n,  Margot R...
# 2   [ Joaquin Phoenix\n,  Robert De Niro\n,  Zazie...
# 3   [ Robert De Niro\n,  Ray Liotta\n,  Joe Pesci\...
# 4   [ Robert De Niro\n,  Sharon Stone\n,  Joe Pesc...
# 5   [ Tom Glynn-Carney\n,  Gábor Czap\n,  Tom Fish...
# 6   [ Robert Downey Jr.\n,  Chris Evans\n,  Mark R...
# 7   [ Brie Larson\n,  Samuel L. Jackson\n,  Ben Me...
# 8   [ Robert Downey Jr.\n,  Chris Hemsworth\n,  Ma...
# 9   [ Mark Hamill\n,  Carrie Fisher\n,  Adam Drive...
# 10  [ Chris Hemsworth\n,  Tom Hiddleston\n,  Cate ...
# 11  [ Jessica Chastain\n,  James McAvoy\n,  Bill H...
# 12  [ Jaeden Martell\n,  Jeremy Ray Taylor\n,  Sop...
# 13  [ Lupita Nyong'o\n,  Winston Duke\n,  Elisabet...
# 14  [ Daniel Kaluuya\n,  Allison Williams\n,  Cath...
# 15  [ Emily Blunt\n,  John Krasinski\n,  Millicent...
# 16  [ James McAvoy\n,  Anya Taylor-Joy\n,  Betty B...
# 17  [ Alex Wolff\n,  Gabriel Byrne\n,  Toni Collet...
# 18  [ Vera Farmiga\n,  Patrick Wilson\n,  Lili Tay...
# 19  [ Patrick Wilson\n,  Vera Farmiga\n,  Madison ...
# 20  [ Patrick Wilson\n,  Rose Byrne\n,  Ty Simpkin...
# 21  [ Anthony LaPaglia\n,  Samara Lee\n,  Miranda ...
# 22  [ Patrick Wilson\n,  Rose Byrne\n,  Ty Simpkin...
# 23  [ Annabelle Wallis\n,  Ward Horton\n,  Tony Am...
# 24  [ Ethan Hawke\n,  Juliet Rylance\n,  Fred Dalt...
#
#                                              duration
# 0   \n                        3h 29min\n          ...
# 1   \n                        2h 41min\n          ...
# 2   \n                        2h 2min\n           ...
# 3   \n                        2h 26min\n          ...
# 4   \n                        2h 58min\n          ...
# 5   \n                        2h 20min\n          ...
# 6   \n                        3h 1min\n           ...
# 7   \n                        2h 3min\n           ...
# 8   \n                        2h 29min\n          ...
# 9   \n                        2h 32min\n          ...
# 10  \n                        2h 10min\n          ...
# 11  \n                        2h 49min\n          ...
# 12  \n                        2h 15min\n          ...
# 13  \n                        1h 56min\n          ...
# 14  \n                        1h 44min\n          ...
# 15  \n                        1h 30min\n          ...
# 16  \n                        1h 57min\n          ...
# 17  \n                        2h 7min\n           ...
# 18  \n                        1h 52min\n          ...
# 19  \n                        2h 14min\n          ...
# 20  \n                        1h 43min\n          ...
# 21  \n                        1h 49min\n          ...
# 22  \n                        1h 46min\n          ...
# 23  \n                        1h 39min\n          ...
# 24  \n                        1h 50min\n          ...

# %% [markdown]
# ## Tidy Data

# %%
def tidy_date(rough):
    time = rough[-8:-3]
    hours = int(time[0])
    minutes = int(time[2:])
    return (hours*60)+minutes

df['minutes'] = df.duration.str.strip().apply(tidy_date)

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.apply.html

# %%
df
# Out:
#                                           film_name  \
# 0                              The Irishman (2019)
# 1          Once Upon a Time... in Hollywood (2019)
# 2                                     Joker (2019)
# 3                                Goodfellas (1990)
# 4                                    Casino (1995)
# 5                                  The King (2019)
# 6                         Avengers: Endgame (2019)
# 7                            Captain Marvel (2019)
# 8                    Avengers: Infinity War (2018)
# 9   Star Wars: Episode VIII - The Last Jedi (2017)
# 10                           Thor: Ragnarok (2017)
# 11                           It Chapter Two (2019)
# 12                                       It (2017)
# 13                                       Us (2019)
# 14                                  Get Out (2017)
# 15                            A Quiet Place (2018)
# 16                                    Split (2016)
# 17                               Hereditary (2018)
# 18                            The Conjuring (2013)
# 19                          The Conjuring 2 (2016)
# 20                                Insidious (2010)
# 21                      Annabelle: Creation (2017)
# 22                     Insidious: Chapter 2 (2013)
# 23                                Annabelle (2014)
# 24                                 Sinister (2012)
#
#                           genres  \
# 0      [Biography, Crime, Drama]
# 1                [Comedy, Drama]
# 2       [Crime, Drama, Thriller]
# 3      [Biography, Crime, Drama]
# 4                 [Crime, Drama]
# 5    [Biography, Drama, History]
# 6     [Action, Adventure, Drama]
# 7    [Action, Adventure, Sci-Fi]
# 8    [Action, Adventure, Sci-Fi]
# 9   [Action, Adventure, Fantasy]
# 10   [Action, Adventure, Comedy]
# 11      [Drama, Fantasy, Horror]
# 12                      [Horror]
# 13   [Horror, Mystery, Thriller]
# 14   [Horror, Mystery, Thriller]
# 15       [Drama, Horror, Sci-Fi]
# 16            [Horror, Thriller]
# 17      [Drama, Horror, Mystery]
# 18   [Horror, Mystery, Thriller]
# 19   [Horror, Mystery, Thriller]
# 20   [Horror, Mystery, Thriller]
# 21   [Horror, Mystery, Thriller]
# 22   [Horror, Mystery, Thriller]
# 23   [Horror, Mystery, Thriller]
# 24   [Horror, Mystery, Thriller]
#
#                                                actors  \
# 0   [ Robert De Niro\n,  Al Pacino\n,  Joe Pesci\n...
# 1   [ Leonardo DiCaprio\n,  Brad Pitt\n,  Margot R...
# 2   [ Joaquin Phoenix\n,  Robert De Niro\n,  Zazie...
# 3   [ Robert De Niro\n,  Ray Liotta\n,  Joe Pesci\...
# 4   [ Robert De Niro\n,  Sharon Stone\n,  Joe Pesc...
# 5   [ Tom Glynn-Carney\n,  Gábor Czap\n,  Tom Fish...
# 6   [ Robert Downey Jr.\n,  Chris Evans\n,  Mark R...
# 7   [ Brie Larson\n,  Samuel L. Jackson\n,  Ben Me...
# 8   [ Robert Downey Jr.\n,  Chris Hemsworth\n,  Ma...
# 9   [ Mark Hamill\n,  Carrie Fisher\n,  Adam Drive...
# 10  [ Chris Hemsworth\n,  Tom Hiddleston\n,  Cate ...
# 11  [ Jessica Chastain\n,  James McAvoy\n,  Bill H...
# 12  [ Jaeden Martell\n,  Jeremy Ray Taylor\n,  Sop...
# 13  [ Lupita Nyong'o\n,  Winston Duke\n,  Elisabet...
# 14  [ Daniel Kaluuya\n,  Allison Williams\n,  Cath...
# 15  [ Emily Blunt\n,  John Krasinski\n,  Millicent...
# 16  [ James McAvoy\n,  Anya Taylor-Joy\n,  Betty B...
# 17  [ Alex Wolff\n,  Gabriel Byrne\n,  Toni Collet...
# 18  [ Vera Farmiga\n,  Patrick Wilson\n,  Lili Tay...
# 19  [ Patrick Wilson\n,  Vera Farmiga\n,  Madison ...
# 20  [ Patrick Wilson\n,  Rose Byrne\n,  Ty Simpkin...
# 21  [ Anthony LaPaglia\n,  Samara Lee\n,  Miranda ...
# 22  [ Patrick Wilson\n,  Rose Byrne\n,  Ty Simpkin...
# 23  [ Annabelle Wallis\n,  Ward Horton\n,  Tony Am...
# 24  [ Ethan Hawke\n,  Juliet Rylance\n,  Fred Dalt...
#
#                                              duration  minutes
# 0   \n                        3h 29min\n          ...      209
# 1   \n                        2h 41min\n          ...      161
# 2   \n                        2h 2min\n           ...      122
# 3   \n                        2h 26min\n          ...      146
# 4   \n                        2h 58min\n          ...      178
# 5   \n                        2h 20min\n          ...      140
# 6   \n                        3h 1min\n           ...      181
# 7   \n                        2h 3min\n           ...      123
# 8   \n                        2h 29min\n          ...      149
# 9   \n                        2h 32min\n          ...      152
# 10  \n                        2h 10min\n          ...      130
# 11  \n                        2h 49min\n          ...      169
# 12  \n                        2h 15min\n          ...      135
# 13  \n                        1h 56min\n          ...      116
# 14  \n                        1h 44min\n          ...      104
# 15  \n                        1h 30min\n          ...       90
# 16  \n                        1h 57min\n          ...      117
# 17  \n                        2h 7min\n           ...      127
# 18  \n                        1h 52min\n          ...      112
# 19  \n                        2h 14min\n          ...      134
# 20  \n                        1h 43min\n          ...      103
# 21  \n                        1h 49min\n          ...      109
# 22  \n                        1h 46min\n          ...      106
# 23  \n                        1h 39min\n          ...       99
# 24  \n                        1h 50min\n          ...      110

# %% [markdown]
# ## Re format data

# %%
df.explode('genre')
# Out:
#       actor      genre                 film  minutes
# 0       NaN  Biography  The Irishman (2019)      209
# 1       NaN      Crime  The Irishman (2019)      209
# 2       NaN      Drama  The Irishman (2019)      209
# 3       NaN  Biography  The Irishman (2019)      209
# 4       NaN      Crime  The Irishman (2019)      209
# ...     ...        ...                  ...      ...
# 1018    NaN    Mystery      Sinister (2012)      110
# 1019    NaN   Thriller      Sinister (2012)      110
# 1020    NaN     Horror      Sinister (2012)      110
# 1021    NaN    Mystery      Sinister (2012)      110
# 1022    NaN   Thriller      Sinister (2012)      110
#
# [1023 rows x 4 columns]

# %%
genres_df
# Out:
#        genres
# 0   Biography
# 0       Crime
# 0       Drama
# 1      Comedy
# 1       Drama
# ..        ...
# 23    Mystery
# 23   Thriller
# 24     Horror
# 24    Mystery
# 24   Thriller
#
# [70 rows x 1 columns]

# %%
actors_df = pd.DataFrame(df.actors.explode())
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.explode.html

# %% [markdown]
# ### Merge new series

# %%
genre_actors_merged = actors_df.merge(genres_df,left_index=True, right_index=True)
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %%
genre_actors_merged
# Out:
#     actors     genres            film_name  minutes
# 0      NaN  Biography  The Irishman (2019)      209
# 0      NaN      Crime  The Irishman (2019)      209
# 0      NaN      Drama  The Irishman (2019)      209
# 0      NaN  Biography  The Irishman (2019)      209
# 0      NaN      Crime  The Irishman (2019)      209
# ..     ...        ...                  ...      ...
# 24     NaN    Mystery      Sinister (2012)      110
# 24     NaN   Thriller      Sinister (2012)      110
# 24     NaN     Horror      Sinister (2012)      110
# 24     NaN    Mystery      Sinister (2012)      110
# 24     NaN   Thriller      Sinister (2012)      110
#
# [1023 rows x 4 columns]

# %%
# more tidying
genre_actors_merged['film_name'] = df['film_name'].str.strip()
genre_actors_merged['minutes'] = df['minutes']
genre_actors_merged['actors'] = df['actors'].str.strip()

# %% [markdown]
# ### House Keeping

# %%
df = genre_actors_merged.reset_index()[['actors','genres','film_name','minutes']]
df.columns = ['actor','genre','film', 'minutes']

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html

# %%
df
# Out:
#      actor      genre                                   film  minutes
# 0      NaN  Biography                    The Irishman (2019)      209
# 1      NaN      Crime                    The Irishman (2019)      209
# 2      NaN      Drama                    The Irishman (2019)      209
# 3      NaN  Biography                    The Irishman (2019)      209
# 4      NaN      Crime                    The Irishman (2019)      209
# ..     ...        ...                                    ...      ...
# 829    NaN  Adventure  Guardians of the Galaxy Vol. 2 (2017)      136
# 830    NaN     Comedy  Guardians of the Galaxy Vol. 2 (2017)      136
# 831    NaN     Action  Guardians of the Galaxy Vol. 2 (2017)      136
# 832    NaN  Adventure  Guardians of the Galaxy Vol. 2 (2017)      136
# 833    NaN     Comedy  Guardians of the Galaxy Vol. 2 (2017)      136
#
# [834 rows x 4 columns]

# %% [markdown]
# # Show duration by genre

# %%
df[['minutes','genre']].groupby('genre').mean()

# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
# Out:
#               minutes
# genre
# Action     138.800000
# Adventure  138.800000
# Biography  165.000000
# Comedy     136.000000
# Crime      163.750000
# Drama      156.282609
# Fantasy    131.272727
# History    140.000000
# Horror     129.454545
# Mystery    131.500000
# Sci-Fi     138.250000
# Thriller   123.333333
